# %% [markdown]
# # The Millionaire Next Door
# ### The surprising secrets of America's Wealthy
#
# The mission of The Millionaire Next Door to it's readers is to enlighten those who are confused and misinformed about what it means to be wealthy. Most Americans have no idea about the true inner workings of a wealthy household. Advertising and Hollywood have done a wonderful job at conditioning everyone to believe that wealth and hyper-consumption go hand in hand. However, as you will learn from this book report, the majority of the rich live well below their means. Unfortunately, most Americans think that they're emulating the rich by immediately consuming any upward swing in cash flow.
#
# This notebook won't necessarily be an overview of everything that the book explains. It's more for you to visually see the characteristics and spending habits of the wealthy. Also might write a bit about the most important part of the chapters.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('fivethirtyeight')

# %%
data = [85, 15]
labels = ['Self Made', 'Inherited/Other']
# colors = sns.color_palette('bright')
plt.pie(data, labels=labels, autopct = '%0.0f%%')
plt.title('Millionaires')
plt.show()

# %% [markdown]
# As shown above, a large majority of millionaire's are not descendants from wealthy families. More than 80% are ordinary people who accumulated their wealth in one generation. They did it slowly, steadily, without signing a multimillion-dollar contract with some sports club, without winning the lottery. These types of millionaires are rare. In the course of an adult's lifetime, the probability of becoming wealthy via such paths is lower than one in four thousand. Contrast these odds with the proportion of American households (3.5%) in the $1 million and over net worth category.

# %% [markdown]
# # Introduction
#
# **How come I am not wealthy?**
#
# Many people ask this question of themselves all the time. Often they are hard-working, well-educated, high-income people. Why, then, are so few affluent?
#
# The reason is that most people have it all wrong about wealth in America. Wealth is not the same as income. If you make a good income each year and spend it all, you are not getting wealthier. You are just living high. **Wealth is what you accumulate, not what you spend.**
#
# How do you become wealthy? Here, too, most people have it wrong. It is rarely luck, or inheritance or advanced degrees or even intelligence that enables people to amass fortunes. **Wealth is more often the result of a lifestyle of hard work, perseverance, planning, and most of all, self-discipline.**
#
#
# **Who becomes wealthy**
#
# Usually the wealthy individual is a business-man who has lived in the same town for all of his adult life. The person owns a small factory, a chain of stores, or a service company. He has married once and remains married. He lives next door to people with a fraction of his wealth. He is a compulsive saver and investor. And he has made his money on his own. *85% of America's millionaires are first generation rich.*
#
# The seven common denominators among those who successfully build wealth are.
#
# **1. They live well below their means.**
#
# **2. They allocate their time, energy, and money efficiently, in ways conducive to building wealth.**
#
# **3. They believe that financial independence is more important than displaying high social status.**
#
# **4. Their parents did not provide economic outpatient care.**
#
# **5. Their adult children are economically self-sufficient.**
#
# **6. They are proficient in targeting market opportunities.**
#
# **7. They chose the right occupation.**

# %% [markdown]
# # Meet the Millionaire Next Door
#
# ## Portrait Of A Millionaire

# %%
data = [20, 66, 14]
labels = ['Retired', 'Self Employed', 'Other (Doctors, Accountants,..)']
plt.pie(data, labels=labels, autopct = '%0.0f%%')
plt.title('Employment Status')
plt.show()

# %% [markdown]
# *Interestingly, self-employed people make up less than 20% of the workers in America but account for 66% of the millionaires.*

# %%
data = [50,37, 8, 5]
labels = ['$131,000 (Median)', '$131,001-$499,999', '$500,000-$999,999', '$1,000,000+']
plt.figure(figsize=(7,7))
plt.pie(data, labels=labels, autopct = '%0.0f%%')
plt.title('Household (taxable) Income')
plt.show()

# %%
data = [50,44, 6]
labels = ['$1,600,000 (Median)', '$1,600,001-$9,999,999', '$10,000,000+']
plt.figure(figsize=(7,7))
plt.pie(data, labels=labels, autopct = '%0.0f%%')
plt.title('Household Networth')
plt.show()

# %%
data = [20, 18, 8, 6, 6, 42]
labels = ['not college graduates', 'master degree', 'law degree', 'medical degree', 'PHD', 'Other']
plt.pie(data, labels=labels, autopct = '%0.0f%%')
plt.title('Education Level')
plt.show()

# %% [markdown]
# *As a group, we are fairly well educated. Only about 1 in 5 are not college graduates. Many of us hold advanced degrees. 18% have master's degree, 8% have law degrees, 6% have medical degrees, and 6% PHDs*

# %% [markdown]
# - I am a 57 year-old male, married with three children. About 70% of us earn 80% or more of our household's income.
#
#
# - Many of the types businesses we are in could be classified as dull-normal. Such as, welding contractors, auctioneers, rice farmers, owners of mobile-home parks, pest controllers, coin and stamp dealers, and paving contractors.
#
#
# - About half of our wives do not work outside the home. The number one occupation for those wives who do work is teacher.
#
#
# - On average, our total annual realized income is less than 7% of our wealth. In other words, we live on less than 7% of our wealth.
#
#
# - Most of us (97%) are homeowners. We live in homes currently valued at an average of $320,000. About half of us have occupied the same home for more than 20 years. Thus, we have enjoyed significant increases in the value of our homes.
#
#
# - Most of us have never felt at a disadvantage because we did not receive any inheritance. More than 80% of us are first generation affluent.
#
#
# - We live well below our means. We wear inexpensive suits and drive American-made cars. Only a minority of us drive current-model-year automobile. Only a minority ever leave our motor vehicles.
#
#
# - Most of our wives are planners and meticulous budgeters. In fact, only 18% of us disagreed with the statement "Charity begins at home." Most of us will tell you that our wives are a lot more conservative with money than we are.
#
#
# - We have a "go-to-hell fund." In other words, we have accumulated enough wealth to live without working for ten or more years.
#
#
# - We have more than 6.5 times the level of wealth of our nonmillionaire neighbors, but, in our neighborhood, these nonmillionaires outnumber us better than 3 to 1. Could it be that they have chosen to trade wealth for acquiring high-status material possessions?
#
#
# - Only 17% of us or or spouses ever attended a private elementary or private high school. But 55% of our children are currently attending or have attended private schools.
#
#
# - As a group, we believe that education is extremely important for ourselves, our children, and our grandchildren. We spend heavily for educations of our offspring.
#
#
# - About two-thirds of us work between 40-50 hours per week.
#
#
# - We are fastidious investors. On average, we invest nearly 20% of our household realized income each year. Most of us invest at least 15$. 79% of us have at least one account with a brokerage company. But we make our own investment decisions.
#
#
# - We hold nearly 20% of our household's wealth in transaction securities such as publicly traded stocks and mutual funds. But we rarely sell our equity investments. We hold even more in our pension plans. On average, 21% of our household's wealth is in our private businesses.
#
#
# - As a group, we feel that our daughters are financially handicapped in comparison to our sons. Men seem to make much more money even with the same occupational categories. That is why most of us would not hesitate to share some of our wealth with our daughters. Our sons and men in general, have the deck of economic cards stacked in their favor. They should not need subsidies from their parents.
#
#
# - What would be the ideal occupations for our children? Our kids should consider providing affluent people with some valuable service. Overall, our most trusted financial advisors are our accountants. Our attorneys are also very important. So we recommended accounting and law to our children.
